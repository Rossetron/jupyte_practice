# %%
import numpy as np

import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df3 = pd.DataFrame(np.random.random(10000).reshape(2500,4),columns = ['A','B','C','D'])

# %%
df3.head()
# Out:
#           A         B         C         D
# 0  0.171099  0.342891  0.112303  0.536893
# 1  0.166424  0.958976  0.420908  0.968240
# 2  0.699976  0.767113  0.148768  0.462593
# 3  0.284499  0.158504  0.847441  0.808260
# 4  0.311962  0.301668  0.121422  0.605521

# %%
df3.plot.scatter(x='A',y='B', s=50,c='red',alpha=.5, figsize=(12,4))

# %%
df3['A'].plot.hist()

# %%
df3['A'].plot.hist(bins=30)

# %% [markdown]
# STYLE SHEETS

# %% [markdown]
# # STYLE SHEETS

# %%
df3['A'].hist()

# %%
import matplotlib.pyplot as ply

# %%
plt.style.use('ggplot')

# %%
df3['A'].hist(alpha=1)

# %%
df3['A'].plot.hist(bins=20, alpha=.5)

# %%
df3.head()
# Out:
#           A         B         C         D
# 0  0.171099  0.342891  0.112303  0.536893
# 1  0.166424  0.958976  0.420908  0.968240
# 2  0.699976  0.767113  0.148768  0.462593
# 3  0.284499  0.158504  0.847441  0.808260
# 4  0.311962  0.301668  0.121422  0.605521

# %%
df3[['A','B']].plot.box()

# %%
df3['D'].plot.kde()

# %%
df3['D'].plot.density(lw=5, ls='--')

# %%
df3.ix[0:30]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   if __name__ == '__main__':
#            A         B         C         D
# 0   0.171099  0.342891  0.112303  0.536893
# 1   0.166424  0.958976  0.420908  0.968240
# 2   0.699976  0.767113  0.148768  0.462593
# 3   0.284499  0.158504  0.847441  0.808260
# 4   0.311962  0.301668  0.121422  0.605521
# 5   0.841659  0.234780  0.884438  0.784487
# 6   0.597166  0.780289  0.177299  0.053978
# 7   0.966445  0.669646  0.763343  0.752310
# 8   0.993232  0.202943  0.538497  0.443287
# 9   0.582478  0.096702  0.738006  0.623142
# 10  0.558172  0.283401  0.096455  0.872250
# 11  0.675216  0.761981  0.375204  0.807235
# 12  0.678164  0.965572  0.602359  0.500371
# ...

# %%
df3.ix[0:30].plot.area(alpha=.5)

# %%
f = plt.figure()
df3.ix[0:30].plot.area(alpha=.5)
plt.legend(loc='center left', bbox_to_anchor=(1.0,0.5))
plt.show()
