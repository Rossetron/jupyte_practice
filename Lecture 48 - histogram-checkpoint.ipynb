# %%
import numpy as np
import pandas as pd
from numpy.random import randn

# %%
from scipy import stats

# %%
import matplotlib as mpl

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
url = 'http://en.wikipedia.org/wiki/Histogram'

# %%
import webbrowser 
webbrowser.open(url)
# Out:
# True

# %%
dataset1 = randn(100)

# %%
plt.hist(dataset1)
# Out:
# (array([  2.,   2.,  14.,  18.,  16.,  22.,  13.,   5.,   5.,   3.]),
#  array([-2.23127239, -1.74580261, -1.26033283, -0.77486305, -0.28939327,
#          0.1960765 ,  0.68154628,  1.16701606,  1.65248584,  2.13795562,
#          2.62342539]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(80)
plt.hist(dataset2, color= 'indianred')
# Out:
# (array([  3.,   8.,   9.,   9.,  14.,   7.,  14.,  12.,   2.,   2.]),
#  array([-2.24991637, -1.80492352, -1.35993067, -0.91493782, -0.46994497,
#         -0.02495213,  0.42004072,  0.86503357,  1.31002642,  1.75501927,
#          2.20001212]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1, normed=True, color='indianred', alpha=0.5, bins=20)
plt.hist(dataset2, normed=True, alpha=0.5, bins=20)
# Out:
# (array([ 0.11236136,  0.05618068,  0.05618068,  0.39326475,  0.33708407,
#          0.16854203,  0.22472271,  0.28090339,  0.39326475,  0.39326475,
#          0.22472271,  0.16854203,  0.5056261 ,  0.28090339,  0.22472271,
#          0.44944543,  0.05618068,  0.05618068,  0.05618068,  0.05618068]),
#  array([-2.24991637, -2.02741994, -1.80492352, -1.5824271 , -1.35993067,
#         -1.13743425, -0.91493782, -0.6924414 , -0.46994497, -0.24744855,
#         -0.02495213,  0.1975443 ,  0.42004072,  0.64253715,  0.86503357,
#          1.08752999,  1.31002642,  1.53252284,  1.75501927,  1.97751569,
#          2.20001212]),
#  <a list of 20 Patch objects>)

# %%
data1 = randn(1000)
data2 = randn(1000)

# %%
sns.jointplot(data1,data2)

# %%
sns.jointplot(data1, data2, kind='hex')
